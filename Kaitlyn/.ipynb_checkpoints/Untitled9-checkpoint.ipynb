# %%
pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Collecting git+https://github.com/JustAnotherArchivist/snscrape.git
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to c:\users\sonou\appdata\local\temp\pip-req-build-voxdqi2y
# Requirement already satisfied: requests[socks] in c:\users\sonou\anaconda3\lib\site-packages (from snscrape==0.3.5.dev96+g47fbc2a) (2.24.0)
# Requirement already satisfied: lxml in c:\users\sonou\anaconda3\lib\site-packages (from snscrape==0.3.5.dev96+g47fbc2a) (4.6.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\sonou\anaconda3\lib\site-packages (from snscrape==0.3.5.dev96+g47fbc2a) (4.9.3)
# Requirement already satisfied: pytz in c:\users\sonou\anaconda3\lib\site-packages (from snscrape==0.3.5.dev96+g47fbc2a) (2020.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sonou\anaconda3\lib\site-packages (from requests[socks]->snscrape==0.3.5.dev96+g47fbc2a) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\sonou\anaconda3\lib\site-packages (from requests[socks]->snscrape==0.3.5.dev96+g47fbc2a) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sonou\anaconda3\lib\site-packages (from requests[socks]->snscrape==0.3.5.dev96+g47fbc2a) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\sonou\anaconda3\lib\site-packages (from requests[socks]->snscrape==0.3.5.dev96+g47fbc2a) (1.25.11)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\users\sonou\anaconda3\lib\site-packages (from requests[socks]->snscrape==0.3.5.dev96+g47fbc2a) (1.7.1)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\sonou\anaconda3\lib\site-packages (from beautifulsoup4->snscrape==0.3.5.dev96+g47fbc2a) (2.0.1)
# Building wheels for collected packages: snscrape
#   Building wheel for snscrape (setup.py): started
#   Building wheel for snscrape (setup.py): finished with status 'done'
#   Created wheel for snscrape: filename=snscrape-0.3.5.dev96+g47fbc2a-py3-none-any.whl size=50496 sha256=c1fb3ca325282fc3b2237106e888e7009bea7f8232d41429c4fe6e918da0b0eb
#   Stored in directory: C:\Users\sonou\AppData\Local\Temp\pip-ephem-wheel-cache-zkvv3jca\wheels\92\42\87\33fa9b18f7a75d02643a9ca3743339aec9be28c6796267c7d8
# Successfully built snscrape
# Installing collected packages: snscrape
#   Attempting uninstall: snscrape
#     Found existing installation: snscrape 0.3.4
#     Uninstalling snscrape-0.3.4:
#       Successfully uninstalled snscrape-0.3.4
# Successfully installed snscrape-0.3.5.dev96+g47fbc2a
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# Using OS library to call CLI commands in Python
os.system("snscrape --jsonl --max-results 100 twitter-search 'from:jack'> user-tweets.json")
# Out:
# 0

# %%
import os

# Using OS library to call CLI commands in Python
os.system("snscrape --jsonl --max-results 500 --since 2020-06-01 twitter-search \"its the elephant until:2020-07-31\" > text-query-tweets.json")
# Out:
# 0

# %%
import pandas as pd

# Reads the json generated from the CLI commands above and creates a pandas dataframe
tweets_df = pd.read_json('text-query-tweets.json', lines=True)

# %%
tweets_df
# Out:
#                                                    url  \
# 0    https://twitter.com/TylerPaulUtt1/status/12889...
# 1    https://twitter.com/EndlessSynthwav/status/128...
# 2    https://twitter.com/aanalyst50/status/12889677...
# 3    https://twitter.com/RozzBozzy/status/128896692...
# 4    https://twitter.com/alfred_hanan/status/128896...
# ..                                                 ...
# 495  https://twitter.com/anshumig/status/1286666680...
# 496  https://twitter.com/REnzerink/status/128666520...
# 497  https://twitter.com/capinafrica/status/1286662...
# 498  https://twitter.com/tim_carey1/status/12866620...
# 499  https://twitter.com/Venkatagiri_GR/status/1286...
#
#                          date  \
# 0   2020-07-30 23:57:02+00:00
# 1   2020-07-30 23:44:04+00:00
# 2   2020-07-30 22:40:40+00:00
# 3   2020-07-30 22:37:18+00:00
# 4   2020-07-30 22:32:44+00:00
# ..                        ...
# 495 2020-07-24 14:16:56+00:00
# 496 2020-07-24 14:11:05+00:00
# 497 2020-07-24 14:00:50+00:00
# 498 2020-07-24 13:58:29+00:00
# 499 2020-07-24 13:58:24+00:00
#
#                                                content  \
# 0    @SiBuduh @langoinstitute do you know the Ko wo...
# 1    @RockstarGames Any idea if the elephant rifle ...
# 2    @realDonaldTrump Trump just keeps ignoring the...
# 3    @cslogan88 Famous 19th century song from Engla...
# 4    @realDonaldTrump #RepublicanTrumpVirus.\nLets ...
# ..                                                 ...
# 495  There is a saying in this part of the woods: "...
# 496  @Dina_Maron Great thread. I haven't seen the d...
# 497  The magnificent Forest Elephants of the Congo'...
# 498  This week in 1984 the DART began running in Du...
# 499  @ShefVaidya @PetaIndia Hi @PetaIndia, animal c...
#
#                                        renderedContent                   id  \
# 0    @SiBuduh @langoinstitute do you know the Ko wo...  1288986997143601152
# 1    @RockstarGames Any idea if the elephant rifle ...  1288983731122966534
# 2    @realDonaldTrump Trump just keeps ignoring the...  1288967774795116550
# 3    @cslogan88 Famous 19th century song from Engla...  1288966929236066309
# 4    @realDonaldTrump #RepublicanTrumpVirus.\nLets ...  1288965780030144512
# ..                                                 ...                  ...
# 495  There is a saying in this part of the woods: "...  1286666680819527680
# 496  @Dina_Maron Great thread. I haven't seen the d...  1286665207012642821
# 497  The magnificent Forest Elephants of the Congo'...  1286662628518113282
# 498  This week in 1984 the DART began running in Du...  1286662039214096384
# 499  @ShefVaidya @PetaIndia Hi @PetaIndia, animal c...  1286662015256350721
#
#                                                   user  \
# 0    {'username': 'TylerPaulUtt1', 'displayname': '...
# 1    {'username': 'EndlessSynthwav', 'displayname':...
# 2    {'username': 'aanalyst50', 'displayname': 'Don...
# 3    {'username': 'RozzBozzy', 'displayname': 'Rozz...
# 4    {'username': 'alfred_hanan', 'displayname': 'A...
# ..                                                 ...
# 495  {'username': 'anshumig', 'displayname': 'Anshu...
# 496  {'username': 'REnzerink', 'displayname': 'Rode...
# 497  {'username': 'capinafrica', 'displayname': 'Ca...
# 498  {'username': 'tim_carey1', 'displayname': 'tim...
# 499  {'username': 'Venkatagiri_GR', 'displayname': ...
#
#                                               outlinks  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 495  [https://twitter.com/SpokespersonCHN/status/12...
# 496                                                 []
# 497                      [http://capturedinafrica.com]
# 498                                                 []
# 499                                                 []
#
#                    tcooutlinks  replyCount  retweetCount  ...  quoteCount  \
# 0                           []           1             0  ...           0
# 1                           []           0             0  ...           0
# 2                           []           0             0  ...           0
# 3                           []           0             0  ...           0
# 4                           []           0             0  ...           0
# ..                         ...         ...           ...  ...         ...
# 495  [https://t.co/ytge38Rkxk]           0             0  ...           0
# 496                         []           0             0  ...           0
# 497  [https://t.co/f7DFV6xSb1]           0             0  ...           1
# 498                         []           1             7  ...           0
# 499                         []           0             1  ...           0
#
#           conversationId  lang  \
# 0    1288307058928947204    en
# 1    1288983731122966534    en
# 2    1288966119676616704    en
# 3    1288965246602838017    en
# 4    1288947487911419905    en
# ..                   ...   ...
# 495  1286666680819527680    en
# 496  1286658931192934400    en
# 497  1286662628518113282    en
# 498  1286662039214096384    en
# 499  1286660774945894400    en
#
#                                                 source  \
# 0    <a href="http://twitter.com/#!/download/ipad" ...
# 1    <a href="http://twitter.com/download/android" ...
# 2    <a href="http://twitter.com/download/iphone" r...
# 3    <a href="https://mobile.twitter.com" rel="nofo...
# 4    <a href="http://twitter.com/download/android" ...
# ..                                                 ...
# 495  <a href="https://mobile.twitter.com" rel="nofo...
# 496  <a href="https://mobile.twitter.com" rel="nofo...
# 497  <a href="https://www.hootsuite.com" rel="nofol...
# 498  <a href="https://mobile.twitter.com" rel="nofo...
# 499  <a href="https://mobile.twitter.com" rel="nofo...
#
#                                sourceUrl          sourceLabel  \
# 0    http://twitter.com/#!/download/ipad     Twitter for iPad
# 1    http://twitter.com/download/android  Twitter for Android
# 2     http://twitter.com/download/iphone   Twitter for iPhone
# 3             https://mobile.twitter.com      Twitter Web App
# 4    http://twitter.com/download/android  Twitter for Android
# ..                                   ...                  ...
# 495           https://mobile.twitter.com      Twitter Web App
# 496           https://mobile.twitter.com      Twitter Web App
# 497            https://www.hootsuite.com       Hootsuite Inc.
# 498           https://mobile.twitter.com      Twitter Web App
# 499           https://mobile.twitter.com      Twitter Web App
#
#                                                  media retweetedTweet  \
# 0                                                 None            NaN
# 1                                                 None            NaN
# 2                                                 None            NaN
# 3                                                 None            NaN
# 4                                                 None            NaN
# ..                                                 ...            ...
# 495                                               None            NaN
# 496                                               None            NaN
# 497  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 498  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 499                                               None            NaN
#
#                                            quotedTweet  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 495  {'url': 'https://twitter.com/SpokespersonCHN/s...
# 496                                               None
# 497                                               None
# 498                                               None
# 499                                               None
#
#                                         mentionedUsers
# 0    [{'username': 'SiBuduh', 'displayname': 'Ed Lu...
# 1    [{'username': 'RockstarGames', 'displayname': ...
# 2    [{'username': 'realDonaldTrump', 'displayname'...
# 3    [{'username': 'cslogan88', 'displayname': 'Chr...
# 4    [{'username': 'realDonaldTrump', 'displayname'...
# ..                                                 ...
# 495  [{'username': 'SpokespersonCHN', 'displayname'...
# 496  [{'username': 'Dina_Maron', 'displayname': 'Di...
# 497                                               None
# 498                                               None
# 499  [{'username': 'ShefVaidya', 'displayname': 'Sh...
#
# [500 rows x 21 columns]

# %%
import snscrape.modules.twitter as sntwitter
import pandas

# Creating list to append tweet data to
tweets_list1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:jack').get_items()):
    if i>100:
        break
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
    
# Creating a dataframe from the tweets list above 
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# %%
tweets_df1
# Out:
#                      Datetime             Tweet Id  \
# 0   2021-03-06 09:55:07+00:00  1368138061276659713
# 1   2021-03-06 09:20:35+00:00  1368129370141974529
# 2   2021-03-06 09:19:24+00:00  1368129072073695232
# 3   2021-03-06 00:08:39+00:00  1367990471759306752
# 4   2021-03-04 13:04:25+00:00  1367460924399882241
# ..                        ...                  ...
# 96  2020-12-16 23:16:02+00:00  1339348591446388736
# 97  2020-12-16 17:09:13+00:00  1339256276010713089
# 98  2020-12-11 05:29:24+00:00  1337268225956925442
# 99  2020-12-11 05:27:45+00:00  1337267809831665664
# 100 2020-12-10 04:13:52+00:00  1336886828461256716
#
#                                                   Text Username
# 0                                         @ConorOkus 💯     jack
# 1              This bag is ♾ 🧡 https://t.co/wT8NXL5tqt     jack
# 2         Matt is incredible 🧡 https://t.co/OImdEaKnXE     jack
# 3                              https://t.co/xCnWG9EqgD     jack
# 4    More from us soon. In the meantime, here’s a p...     jack
# ..                                                 ...      ...
# 96                      💯💯💯💯💯💯 https://t.co/6E3apTMLa1     jack
# 97   Grateful for all the heart, humility, and resi...     jack
# 98                                     @Larakate Never     jack
# 99   #NowPlaying "Man On The Moon III: The Chosen" ...     jack
# 100  @Ola__Idowu @michaelmontano @dantley @Spotify ...     jack
#
# [101 rows x 4 columns]

# %%
 import snscrape.modules.twitter as sntwitter
import pandas

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('its the elephant since:2020-06-01 until:2020-07-31').get_items()):
    if i>1000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
    
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# %%
tweets_df2
# Out:
#                       Datetime             Tweet Id  \
# 0    2020-07-30 23:57:02+00:00  1288986997143601152
# 1    2020-07-30 23:44:04+00:00  1288983731122966534
# 2    2020-07-30 22:40:40+00:00  1288967774795116550
# 3    2020-07-30 22:37:18+00:00  1288966929236066309
# 4    2020-07-30 22:32:44+00:00  1288965780030144512
# ...                        ...                  ...
# 996  2020-07-20 03:37:09+00:00  1285056122907324416
# 997  2020-07-20 03:25:34+00:00  1285053206368673792
# 998  2020-07-20 03:22:02+00:00  1285052319105789952
# 999  2020-07-20 03:20:13+00:00  1285051859514920960
# 1000 2020-07-20 03:13:13+00:00  1285050097680568321
#
#                                                    Text         Username
# 0     @SiBuduh @langoinstitute do you know the Ko wo...    TylerPaulUtt1
# 1     @RockstarGames Any idea if the elephant rifle ...  EndlessSynthwav
# 2     @realDonaldTrump Trump just keeps ignoring the...       aanalyst50
# 3     @cslogan88 Famous 19th century song from Engla...        RozzBozzy
# 4     @realDonaldTrump #RepublicanTrumpVirus.\nLets ...     alfred_hanan
# ...                                                 ...              ...
# 996   How does an #elephant calf learn to use its tr...    RamanSpoorthy
# 997   Daily Sketch \nArt and Photography by Irish Ke...         Irishflw
# 998   @revsblair @trigsjourney @FirstTimeSinceA @dda...        shamanrok
# 999   he's still bragging about the dementia test.  ...        Raine0801
# 1000  HAHAHAHA #narcissist DUMB #disinfectant CROOK ...           ormiga
#
# [1001 rows x 4 columns]
